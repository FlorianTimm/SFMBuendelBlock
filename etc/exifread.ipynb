# %%
import exifread

# %%
f = open("../example_data/bildverband2/DJI_0289.JPG", 'rb')

# Return Exif tags
tags = exifread.process_file(f)

# %%
tags
# Out:
# {'Image ImageDescription': (0x010E) ASCII=DCIM\101MEDIA\DJI_0289.JPG @ 1012,
#  'Image Make': (0x010F) ASCII=DJI @ 1039,
#  'Image Model': (0x0110) ASCII=FC7303 @ 1069,
#  'Image Orientation': (0x0112) Short=Horizontal (normal) @ 54,
#  'Image XResolution': (0x011A) Ratio=72 @ 1099,
#  'Image YResolution': (0x011B) Ratio=72 @ 1107,
#  'Image ResolutionUnit': (0x0128) Short=Pixels/Inch @ 90,
#  'Image Software': (0x0131) ASCII=v01.43.0067 @ 1115,
#  'Image DateTime': (0x0132) ASCII=2022:10:23 13:15:01 @ 1139,
#  'Image YCbCrPositioning': (0x0213) Short=Centered @ 126,
#  'Image ExifOffset': (0x8769) Long=182 @ 138,
#  'GPS GPSVersionID': (0x0000) Byte=[2, 3, 0, 0] @ 696,
#  'GPS GPSLatitudeRef': (0x0001) ASCII=N @ 708,
#  'GPS GPSLatitude': (0x0002) Ratio=[53, 34, 448657/10000] @ 18231,
#  'GPS GPSLongitudeRef': (0x0003) ASCII=E @ 732,
#  'GPS GPSLongitude': (0x0004) Ratio=[9, 53, 592347/10000] @ 18255,
#  'GPS GPSAltitudeRef': (0x0005) Byte=0 @ 756,
# ...
